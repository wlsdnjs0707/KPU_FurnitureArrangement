# %% [markdown]
# 시작하기전 구글 드라이브의 MyDrive에 dataset이름의 새폴더를 만들고 이 폴더로 다운로드받은 zip파일을 업로드해야함

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import numpy as np
import matplotlib.pyplot as plt

# %%
# 구글 드라이브 폴더 마운트 (코랩을 사용하는 경우)
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 압축 파일의 위치 (구글 드라이브 - 내 드라이브 위치)
drive_path = "/content/drive/MyDrive/"
source_filename = drive_path + "dataset/Interior_Dataset.zip"

# 저장할 경로
extract_folder = "dataset/" # 코랩 환경에 임시 저장

# 압축 해제
import shutil
shutil.unpack_archive(source_filename, extract_folder)

# %%
# 훈련 셋, 검증 셋 저장 위치 지정
train_dir = extract_folder + "training_set"
valid_dir = extract_folder + "test_set"
print(train_dir)
print(valid_dir)
# Out:
# dataset/training_set
# dataset/test_set

# %%
# 이미지 데이터 제너레이터 정의 (Augmentation 미적용)
image_gen = ImageDataGenerator(rescale = (1/255.0))
image_gen

# %%
# flow_from_directory 함수로 폴더에서 이미지를 가져와 제너레이터 객체로 정리
train_gen = image_gen.flow_from_directory(train_dir, batch_size = 10, target_size = (224,224), classes = ['Casual Style','Classic Style','Modern Style','Natural Style'],
                                          class_mode = 'sparse')

valid_gen = image_gen.flow_from_directory(valid_dir, batch_size = 10, target_size = (224,224), classes = ['Casual Style','Classic Style','Modern Style','Natural Style'],
                                          class_mode = 'sparse')
# Out:
# Found 480 images belonging to 4 classes.
# Found 120 images belonging to 4 classes.

# %%
# 샘플 이미지 출력
class_labels = ['Casual Style','Classic Style','Modern Style','Natural Style']
batch = next(train_gen)

images, labels = batch[0], batch[1]

plt.figure(figsize = (15,9))
for i in range(10):
  ax = plt.subplot(2,5,i+1)
  plt.imshow(images[i])
  plt.title(class_labels[labels[i].astype(np.int)])
  plt.axis('off')

plt.tight_layout()  
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Sequential API를 사용하여 샘플 모델 형성

def build_model():

  model = tf.keras.Sequential([
                               
      # Convolution 층
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Conv2D(32,(3,3), padding = 'same', activation = 'relu', input_shape = (224,224,3)),
      tf.keras.layers.MaxPooling2D((2,2)),
      
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Conv2D(64, (3,3), padding = 'same', activation = 'relu'),
      tf.keras.layers.MaxPooling2D((2,2)),

      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Conv2D(128, (3,3), padding = 'same', activation = 'relu'),
      tf.keras.layers.MaxPooling2D((2,2)),

      # Classifier 출력층
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(256, activation = 'relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.Dense(4, activation = 'softmax')
      ])
  
  return model

model = build_model()

# %%
from gc import callbacks
# 모델 컴파일
model.compile(optimizer = 'adam',
              loss ='sparse_categorical_crossentropy',
              metrics = 'accuracy')

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint('best-cnn-interior-model.h5', 
                                                   save_best_only = True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience = 7, 
                                                     restore_best_weights= True)

# 모델 훈련
history = model.fit(train_gen, validation_data = valid_gen, epochs = 40,
                    callbacks = [checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/40
# 48/48 [==============================] - 14s 265ms/step - loss: 22.9033 - accuracy: 0.3417 - val_loss: 1.9795 - val_accuracy: 0.3667
# Epoch 2/40
# 48/48 [==============================] - 12s 259ms/step - loss: 1.5850 - accuracy: 0.5500 - val_loss: 1.2989 - val_accuracy: 0.3583
# Epoch 3/40
# 48/48 [==============================] - 12s 245ms/step - loss: 0.9493 - accuracy: 0.6167 - val_loss: 1.5341 - val_accuracy: 0.2500
# Epoch 4/40
# 48/48 [==============================] - 12s 256ms/step - loss: 0.8087 - accuracy: 0.6583 - val_loss: 1.1568 - val_accuracy: 0.4583
# Epoch 5/40
# 48/48 [==============================] - 12s 245ms/step - loss: 0.6819 - accuracy: 0.7396 - val_loss: 1.2675 - val_accuracy: 0.4667
# Epoch 6/40
# 48/48 [==============================] - 13s 265ms/step - loss: 0.6128 - accuracy: 0.7667 - val_loss: 0.7847 - val_accuracy: 0.7167
# Epoch 7/40
# 48/48 [==============================] - 12s 255ms/step - loss: 0.4252 - accuracy: 0.8396 - val_loss: 0.8665 - val_accuracy: 0.6833
# Epoch 8/40
# 48/48 [==============================] - 11s 241ms/step - loss: 0.4223 - accuracy: 0.8354 - val_loss: 0.8566 - val_accuracy: 0.6167
# Epoch 9/40
# 48/48 [==============================] - 11s 238ms/step - loss: 0.3461 - accuracy: 0.8750 - val_loss: 0.8805 - val_accuracy: 0.6667
# Epoch 10/40
# 48/48 [==============================] - 12s 260ms/step - loss: 0.2961 - accuracy: 0.9000 - val_loss: 0.7479 - val_accuracy: 0.7167
# Epoch 11/40
# 48/48 [==============================] - 12s 243ms/step - loss: 0.5402 - accuracy: 0.8000 - val_loss: 0.9420 - val_accuracy: 0.6083
# Epoch 12/40
# 48/48 [==============================] - 13s 263ms/step - loss: 0.5263 - accuracy: 0.7792 - val_loss: 0.7077 - val_accuracy: 0.7250
# Epoch 13/40
# 48/48 [==============================] - 12s 247ms/step - loss: 0.4142 - accuracy: 0.8354 - val_loss: 1.7679 - val_accuracy: 0.5750
# Epoch 14/40
# 48/48 [==============================] - 12s 252ms/step - loss: 0.4664 - accuracy: 0.8313 - val_loss: 1.0462 - val_accuracy: 0.6833
# Epoch 15/40
# 48/48 [==============================] - 12s 250ms/step - loss: 0.3412 - accuracy: 0.8500 - val_loss: 1.9531 - val_accuracy: 0.5167
# Epoch 16/40
# 48/48 [==============================] - 12s 247ms/step - loss: 0.3172 - accuracy: 0.8729 - val_loss: 0.9040 - val_accuracy: 0.6917
# Epoch 17/40
# 48/48 [==============================] - 12s 250ms/step - loss: 0.3284 - accuracy: 0.8604 - val_loss: 0.8593 - val_accuracy: 0.7333
# Epoch 18/40
# 48/48 [==============================] - 12s 255ms/step - loss: 0.3235 - accuracy: 0.8667 - val_loss: 1.2157 - val_accuracy: 0.6583
# Epoch 19/40
# 48/48 [==============================] - 12s 251ms/step - loss: 0.2878 - accuracy: 0.8583 - val_loss: 0.8560 - val_accuracy: 0.7750

# %%
# 손실함수, 정확도 그래프 그리기
def plot_loss_acc(history):
  fig, axes =  plt.subplots(1,2, figsize = (12,4))
  axes[0].plot( history.history['loss'])
  axes[0].plot(history.history['val_loss'])
  axes[0].legend(labels = ['Training', 'Validation'])
  axes[0].set_title('Loss')
  
  axes[1].plot(history.history['accuracy'])
  axes[1].plot(history.history['val_accuracy'])
  axes[1].legend(labels = ['Training', 'Validation'])
  axes[1].set_title('Accuracy')

plot_loss_acc(history)

# %%
model.evaluate(valid_gen)
# Out:
# 12/12 [==============================] - 2s 193ms/step - loss: 0.7077 - accuracy: 0.7250
# [0.707658052444458, 0.7250000238418579]

# %%
# 예측

class_labels = ['Casual Style','Classic Style','Modern Style','Natural Style']

batch = next(valid_gen)
print(batch[1])
images, labels = batch[0], batch[1]
print(labels)

predictions = model.predict(batch[0])
# Out:
# [0. 1. 0. 1. 1. 1. 3. 0. 0. 3.]
# [0. 1. 0. 1. 1. 1. 3. 0. 0. 3.]

# %%
predictions.shape
print(predictions[0])
# Out:
# [0.5164505  0.16844814 0.01504553 0.30005577]

# %%
def plot_image(i, predictions_array, true_label, img): #순서, 예측확률
  predictions_array, img = predictions_array[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
 
  plt.imshow(img, cmap=plt.cm.binary)
 
  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'
 
  plt.xlabel("{} {:2.0f}% ({})".format(class_labels[predicted_label],
                                100*np.max(predictions_array),
                                class_labels[int(true_label)]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  thisplot = plt.bar(range(4), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)
 
  thisplot[predicted_label].set_color('red')
  thisplot[np.argmax(true_label)].set_color('blue')

  
num_rows = 2
num_cols = 5
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))


for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, labels[i], images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions,labels)
plt.show()

# %%
# 이미지 데이터 제너레이터 정의 (Augmentation 적용)
image_gen_aug = ImageDataGenerator(rescale = 1/255.0,
                                   horizontal_flip = True,
                                   rotation_range = 30
                                    )

# flow_from_directory 함수로 폴더에서 이미지 가져와서 제너레이터 객체로 정리
train_gen_aug = image_gen_aug.flow_from_directory(train_dir,
                                                  batch_size = 10,
                                                  target_size = (224,224),
                                                  classes = ['Casual Style','Classic Style','Modern Style','Natural Style'],
                                                  class_mode = 'sparse',
                                                  )

valid_gen_aug = image_gen_aug.flow_from_directory(valid_dir,
                                                  batch_size = 10,
                                                  target_size = (224,224),
                                                  classes = ['Casual Style','Classic Style','Modern Style','Natural Style'],
                                                  class_mode = 'sparse',
                                                  )

# 모델 생성
model_aug = build_model()

# 모델 컴파일
model_aug.compile(optimizer = tf.optimizers.Adam(learning_rate = 0.001),
                  loss = 'sparse_categorical_crossentropy',
                  metrics = 'accuracy')

# 모델 훈련
history_aug = model_aug.fit(train_gen_aug, validation_data = valid_gen_aug, epochs = 40)
# Out:
# Found 480 images belonging to 4 classes.
# Found 120 images belonging to 4 classes.
# Epoch 1/40
# 48/48 [==============================] - 21s 417ms/step - loss: 20.5687 - accuracy: 0.3583 - val_loss: 2.3354 - val_accuracy: 0.2500
# Epoch 2/40
# 48/48 [==============================] - 19s 406ms/step - loss: 1.4944 - accuracy: 0.4479 - val_loss: 1.4150 - val_accuracy: 0.2583
# Epoch 3/40
# 48/48 [==============================] - 19s 401ms/step - loss: 1.1532 - accuracy: 0.4958 - val_loss: 1.3520 - val_accuracy: 0.2500
# Epoch 4/40
# 48/48 [==============================] - 19s 403ms/step - loss: 1.0101 - accuracy: 0.5750 - val_loss: 1.2754 - val_accuracy: 0.4917
# Epoch 5/40
# 48/48 [==============================] - 19s 406ms/step - loss: 1.1078 - accuracy: 0.4958 - val_loss: 1.3407 - val_accuracy: 0.3417
# Epoch 6/40
# 48/48 [==============================] - 20s 427ms/step - loss: 1.0657 - accuracy: 0.5500 - val_loss: 1.1215 - val_accuracy: 0.6250
# Epoch 7/40
# 48/48 [==============================] - 19s 406ms/step - loss: 1.0351 - accuracy: 0.5479 - val_loss: 1.1044 - val_accuracy: 0.5500
# Epoch 8/40
# 48/48 [==============================] - 19s 400ms/step - loss: 0.9916 - accuracy: 0.5729 - val_loss: 1.0228 - val_accuracy: 0.6083
# Epoch 9/40
# 48/48 [==============================] - 19s 404ms/step - loss: 0.9036 - accuracy: 0.6458 - val_loss: 1.0205 - val_accuracy: 0.5917
# Epoch 10/40
# 48/48 [==============================] - 19s 407ms/step - loss: 0.9872 - accuracy: 0.5646 - val_loss: 1.0806 - val_accuracy: 0.6000
# Epoch 11/40
# 48/48 [==============================] - 19s 402ms/step - loss: 0.9367 - accuracy: 0.6125 - val_loss: 1.0219 - val_accuracy: 0.6333
# Epoch 12/40
# 48/48 [==============================] - 19s 401ms/step - loss: 0.9419 - accuracy: 0.6229 - val_loss: 0.9771 - val_accuracy: 0.5833
# Epoch 13/40
# 48/48 [==============================] - 19s 408ms/step - loss: 0.8870 - accuracy: 0.6708 - val_loss: 0.9836 - val_accuracy: 0.6667
# Epoch 14/40
# 48/48 [==============================] - 19s 402ms/step - loss: 0.8930 - accuracy: 0.6250 - val_loss: 1.0519 - val_accuracy: 0.6167
# Epoch 15/40
# 48/48 [==============================] - 19s 403ms/step - loss: 0.9757 - accuracy: 0.6000 - val_loss: 0.9478 - val_accuracy: 0.5750
# Epoch 16/40
# 48/48 [==============================] - 19s 400ms/step - loss: 0.9072 - accuracy: 0.6313 - val_loss: 1.0074 - val_accuracy: 0.6417
# Epoch 17/40
# 48/48 [==============================] - 19s 403ms/step - loss: 0.8559 - accuracy: 0.6562 - val_loss: 0.9072 - val_accuracy: 0.6333
# Epoch 18/40
# 48/48 [==============================] - 19s 406ms/step - loss: 0.8680 - accuracy: 0.6583 - val_loss: 1.2390 - val_accuracy: 0.6250
# Epoch 19/40
# 48/48 [==============================] - 19s 407ms/step - loss: 0.9493 - accuracy: 0.5938 - val_loss: 1.0673 - val_accuracy: 0.6750
# Epoch 20/40
# 48/48 [==============================] - 20s 410ms/step - loss: 0.8169 - accuracy: 0.6771 - val_loss: 1.1705 - val_accuracy: 0.6583
# Epoch 21/40
# 48/48 [==============================] - 19s 403ms/step - loss: 0.8969 - accuracy: 0.6313 - val_loss: 0.9912 - val_accuracy: 0.6583
# Epoch 22/40
# 48/48 [==============================] - 20s 408ms/step - loss: 0.7954 - accuracy: 0.6750 - val_loss: 1.0744 - val_accuracy: 0.7250
# Epoch 23/40
# 48/48 [==============================] - 19s 407ms/step - loss: 0.7994 - accuracy: 0.6812 - val_loss: 1.0538 - val_accuracy: 0.6917
# Epoch 24/40
# 48/48 [==============================] - 19s 407ms/step - loss: 0.7586 - accuracy: 0.6771 - val_loss: 1.1431 - val_accuracy: 0.6167
# Epoch 25/40
# 48/48 [==============================] - 19s 405ms/step - loss: 0.8301 - accuracy: 0.6687 - val_loss: 1.9306 - val_accuracy: 0.3917
# Epoch 26/40
# 48/48 [==============================] - 19s 404ms/step - loss: 0.8494 - accuracy: 0.6313 - val_loss: 1.0311 - val_accuracy: 0.6917
# Epoch 27/40
# 48/48 [==============================] - 20s 406ms/step - loss: 0.8491 - accuracy: 0.6354 - val_loss: 1.0700 - val_accuracy: 0.6667
# Epoch 28/40
# 48/48 [==============================] - 19s 406ms/step - loss: 0.9274 - accuracy: 0.5792 - val_loss: 1.2363 - val_accuracy: 0.6167
# Epoch 29/40
# 48/48 [==============================] - 19s 406ms/step - loss: 0.8599 - accuracy: 0.6458 - val_loss: 0.9839 - val_accuracy: 0.6417
# Epoch 30/40
# 48/48 [==============================] - 19s 407ms/step - loss: 0.8214 - accuracy: 0.6521 - val_loss: 1.0590 - val_accuracy: 0.6833
# Epoch 31/40
# 48/48 [==============================] - 19s 408ms/step - loss: 0.7843 - accuracy: 0.6583 - val_loss: 0.9863 - val_accuracy: 0.6333
# Epoch 32/40
# 48/48 [==============================] - 20s 409ms/step - loss: 0.8847 - accuracy: 0.6667 - val_loss: 1.1957 - val_accuracy: 0.5083
# Epoch 33/40
# 48/48 [==============================] - 19s 407ms/step - loss: 0.6762 - accuracy: 0.7188 - val_loss: 1.0803 - val_accuracy: 0.6750
# Epoch 34/40
# 48/48 [==============================] - 19s 404ms/step - loss: 0.7390 - accuracy: 0.6938 - val_loss: 1.0214 - val_accuracy: 0.6583
# Epoch 35/40
# 48/48 [==============================] - 20s 409ms/step - loss: 0.7095 - accuracy: 0.7104 - val_loss: 1.1489 - val_accuracy: 0.7000
# Epoch 36/40
# 48/48 [==============================] - 19s 403ms/step - loss: 0.7801 - accuracy: 0.6854 - val_loss: 1.2162 - val_accuracy: 0.6417
# Epoch 37/40
# 48/48 [==============================] - 20s 409ms/step - loss: 0.8280 - accuracy: 0.6521 - val_loss: 1.1437 - val_accuracy: 0.6917
# Epoch 38/40
# 48/48 [==============================] - 19s 405ms/step - loss: 0.8543 - accuracy: 0.6646 - val_loss: 1.2118 - val_accuracy: 0.6667
# Epoch 39/40
# 48/48 [==============================] - 19s 408ms/step - loss: 0.8288 - accuracy: 0.6687 - val_loss: 1.1231 - val_accuracy: 0.6750
# Epoch 40/40
# 48/48 [==============================] - 20s 409ms/step - loss: 0.6978 - accuracy: 0.7229 - val_loss: 1.8266 - val_accuracy: 0.6167

# %%
# VGG16 학습모델을 신경곱(CNN)층까지 전이학습

from keras.applications.vgg16 import VGG16

transfer_model = VGG16(input_shape = (224,224,3), weights = 'imagenet', include_top =False)

# transfer_model의 기존 가중치 고정
for layer in transfer_model.layers:
  layer.trainable = False

tf.keras.utils.plot_model(transfer_model)

# %%
def build_trainsfer_VGG16_classifier() :
                # VGG16 합성곱 층을 전이학습                     
          model = tf.keras.Sequential([transfer_model,
                                       
                # Classifier 출력층                      
                tf.keras.layers.Flatten(),
                tf.keras.layers.Dense(64, activation = 'relu'),
                tf.keras.layers.Dropout(0.5),
                tf.keras.layers.Dense(4, activation = 'softmax')
])
          
          return model

vgg16_interior_model = build_trainsfer_VGG16_classifier()
vgg16_interior_model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_10 (Flatten)        (None, 25088)             0
#
#  dense_22 (Dense)            (None, 64)                1605696
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_23 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 16,320,644
# Trainable params: 1,605,956
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# 모델 컴파일
vgg16_interior_model.compile(optimizer = 'adam',
              loss ='sparse_categorical_crossentropy',
              metrics = 'accuracy')

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint('best-cnn-interior-model.h5', 
                                                   save_best_only = True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience = 7, 
                                                     restore_best_weights= True)

# 모델 훈련
history = vgg16_interior_model.fit(train_gen, validation_data = valid_gen, epochs = 40,
                    callbacks = [checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/40
# 48/48 [==============================] - 15s 290ms/step - loss: 1.6069 - accuracy: 0.3333 - val_loss: 1.2442 - val_accuracy: 0.3917
# Epoch 2/40
# 48/48 [==============================] - 14s 286ms/step - loss: 1.2021 - accuracy: 0.3896 - val_loss: 1.0139 - val_accuracy: 0.5833
# Epoch 3/40
# 48/48 [==============================] - 14s 286ms/step - loss: 1.1063 - accuracy: 0.4812 - val_loss: 0.9202 - val_accuracy: 0.5750
# Epoch 4/40
# 48/48 [==============================] - 14s 290ms/step - loss: 0.9451 - accuracy: 0.5583 - val_loss: 0.8998 - val_accuracy: 0.6083
# Epoch 5/40
# 48/48 [==============================] - 15s 310ms/step - loss: 0.8872 - accuracy: 0.5646 - val_loss: 0.8352 - val_accuracy: 0.7083
# Epoch 6/40
# 48/48 [==============================] - 13s 274ms/step - loss: 0.7844 - accuracy: 0.6229 - val_loss: 0.6922 - val_accuracy: 0.7500
# Epoch 7/40
# 48/48 [==============================] - 13s 272ms/step - loss: 0.7472 - accuracy: 0.6521 - val_loss: 0.6958 - val_accuracy: 0.7417
# Epoch 8/40
# 48/48 [==============================] - 13s 271ms/step - loss: 0.7753 - accuracy: 0.6146 - val_loss: 0.7158 - val_accuracy: 0.7667
# Epoch 9/40
# 48/48 [==============================] - 13s 268ms/step - loss: 0.6681 - accuracy: 0.6667 - val_loss: 0.7307 - val_accuracy: 0.7417
# Epoch 10/40
# 48/48 [==============================] - 14s 292ms/step - loss: 0.7604 - accuracy: 0.5917 - val_loss: 0.6833 - val_accuracy: 0.7333
# Epoch 11/40
# 48/48 [==============================] - 14s 282ms/step - loss: 0.6369 - accuracy: 0.6583 - val_loss: 0.6300 - val_accuracy: 0.7833
# Epoch 12/40
# 48/48 [==============================] - 14s 297ms/step - loss: 0.6373 - accuracy: 0.6708 - val_loss: 0.6690 - val_accuracy: 0.7667
# Epoch 13/40
# 48/48 [==============================] - 14s 283ms/step - loss: 0.6539 - accuracy: 0.6500 - val_loss: 0.7017 - val_accuracy: 0.7583
# Epoch 14/40
# 48/48 [==============================] - 13s 278ms/step - loss: 0.6316 - accuracy: 0.6729 - val_loss: 0.6645 - val_accuracy: 0.7667
# Epoch 15/40
# 48/48 [==============================] - 13s 280ms/step - loss: 0.5820 - accuracy: 0.6812 - val_loss: 0.6523 - val_accuracy: 0.7500
# Epoch 16/40
# 48/48 [==============================] - 13s 279ms/step - loss: 0.6256 - accuracy: 0.6792 - val_loss: 0.6228 - val_accuracy: 0.7750
# Epoch 17/40
# 48/48 [==============================] - 13s 274ms/step - loss: 0.6410 - accuracy: 0.6917 - val_loss: 0.6008 - val_accuracy: 0.8000
# Epoch 18/40
# 48/48 [==============================] - 13s 265ms/step - loss: 0.6098 - accuracy: 0.6875 - val_loss: 0.6124 - val_accuracy: 0.8083
# Epoch 19/40
# 48/48 [==============================] - 13s 255ms/step - loss: 0.5795 - accuracy: 0.7042 - val_loss: 0.6196 - val_accuracy: 0.7833
# Epoch 20/40
# 48/48 [==============================] - 13s 257ms/step - loss: 0.6473 - accuracy: 0.6313 - val_loss: 0.6156 - val_accuracy: 0.8000
# Epoch 21/40
# 48/48 [==============================] - 13s 263ms/step - loss: 0.5390 - accuracy: 0.7063 - val_loss: 0.6662 - val_accuracy: 0.7583
# Epoch 22/40
# 48/48 [==============================] - 13s 260ms/step - loss: 0.5812 - accuracy: 0.6750 - val_loss: 0.6411 - val_accuracy: 0.7833
# Epoch 23/40
# 48/48 [==============================] - 13s 261ms/step - loss: 0.5185 - accuracy: 0.7208 - val_loss: 0.6684 - val_accuracy: 0.7917
# Epoch 24/40
# 48/48 [==============================] - 13s 265ms/step - loss: 0.5309 - accuracy: 0.7229 - val_loss: 0.6356 - val_accuracy: 0.8083

# %%
# 손실함수, 정확도 그래프 그리기
def plot_loss_acc(history):
  fig, axes =  plt.subplots(1,2, figsize = (12,4))
  axes[0].plot( history.history['loss'])
  axes[0].plot(history.history['val_loss'])
  axes[0].legend(labels = ['Training', 'Validation'])
  axes[0].set_title('Loss')
  
  axes[1].plot(history.history['accuracy'])
  axes[1].plot(history.history['val_accuracy'])
  axes[1].legend(labels = ['Training', 'Validation'])
  axes[1].set_title('Accuracy')

plot_loss_acc(history)

# %%
vgg16_interior_model.evaluate(valid_gen)
# Out:
# 12/12 [==============================] - 3s 252ms/step - loss: 0.6008 - accuracy: 0.8000
# [0.6007751226425171, 0.800000011920929]

# %%
# 예측

class_labels = ['Casual Style','Classic Style','Modern Style','Natural Style']

batch = next(valid_gen)
print(batch[1])
images, labels = batch[0], batch[1]
print(labels)

predictions = vgg16_interior_model.predict(batch[0])
# Out:
# [0. 3. 1. 1. 0. 3. 0. 0. 1. 3.]
# [0. 3. 1. 1. 0. 3. 0. 0. 1. 3.]

# %%
def plot_image(i, predictions_array, true_label, img): #순서, 예측확률
  predictions_array, img = predictions_array[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
 
  plt.imshow(img, cmap=plt.cm.binary)
 
  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'
 
  plt.xlabel("{} {:2.0f}% ({})".format(class_labels[predicted_label],
                                100*np.max(predictions_array),
                                class_labels[int(true_label)]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  thisplot = plt.bar(range(4), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)
 
  thisplot[predicted_label].set_color('red')
  thisplot[np.argmax(true_label)].set_color('blue')

  
num_rows = 2
num_cols = 5
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))


for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, labels[i], images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions,labels)
plt.show()
